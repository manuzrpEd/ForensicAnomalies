# %% [markdown]
# In this notebook we download the raw LAPD crime data and store locally as a CSV file.

# %% [markdown]
# NIBR stands for the National Incident-Based Reporting System, a U.S. system used by law enforcement to report detailed information on crimes to the Federal Bureau of Investigation (FBI)

# %%
from sodapy import Socrata
import pandas as pd

# Socrata client
DOMAIN = "data.lacity.org"
client = Socrata(DOMAIN, None)  # None = anonymous access

# Dataset IDs: https://data.lacity.org/
OFFENSES_ID = "y8y3-fqfu"
VICTIMS_ID = "gqf2-vm2j"

# ---- Fetch offenses ----
offenses = client.get(OFFENSES_ID, limit=500000)
df_off = pd.DataFrame.from_records(offenses)
print("Offenses:", df_off.shape)

# ---- Fetch victims ----
victims = client.get(VICTIMS_ID, limit=500000)
df_vic = pd.DataFrame.from_records(victims)
print("Victims:", df_vic.shape)

# ---- Merge ----
if "caseno" in df_off.columns and "caseno" in df_vic.columns:
    df = df_off.merge(df_vic, on="caseno", how="left")
else:
    raise ValueError("caseno not found in one of the datasets")

print("Merged:", df.shape)

# Save locally
df.to_csv("lapd_offenses_victims_merged.csv", index=False)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Offenses: (212391, 28)
# Victims: (197422, 16)
# Merged: (243639, 43)

# %%
df_off.columns
# Out:
# Index(['caseno', 'uniquenibrno', 'date_rptd', 'date_occ', 'time_occ', 'area',
#        'area_name', 'rpt_dist_no', 'totaloffensecount', 'group', 'nibr_code',
#        'nibr_description', 'crime_against', 'premis_cd', 'premis_desc',
#        'weapon_used_cd', 'weapon_desc', 'status', 'status_desc',
#        'totalvictimcount', 'victim_shot', 'domestic_violence_crime',
#        'hate_crime', 'gang_related_crime', 'transit_related_crime',
#        'homeless_victim_crime', 'homeless_suspect_crime',
#        'homeless_arrestee_crime'],
#       dtype='object')

# %%
df_vic.columns
# Out:
# Index(['caseno', 'uniquevictimno', 'date_rptd', 'date_occ', 'time_occ', 'area',
#        'area_name', 'rpt_dist_no', 'totalvictimcount', 'victim_type',
#        'victim_shot', 'status', 'status_desc', 'vict_age', 'vict_sex',
#        'vict_descent'],
#       dtype='object')

# %%
# cases with multiple victims
df_vic[(df_vic["totalvictimcount"].astype(float)>1) & (df_vic["caseno"].isin(df_off["caseno"].unique()))]
# Out:
#             caseno uniquevictimno                date_rptd  \
# 6         25174642     25174642_1  2025-09-17T00:00:00.000
# 27        25169629     25169629_0  2025-09-09T00:00:00.000
# 57        25036161     25036161_1  2025-03-02T00:00:00.000
# 59        25029792     25029792_0  2025-02-21T00:00:00.000
# 70        25094706     25094706_1  2025-05-24T00:00:00.000
# ...            ...            ...                      ...
# 197393  C259035710   C259035710_2  2025-09-06T00:00:00.000
# 197405    25088614     25088614_0  2025-05-16T00:00:00.000
# 197410    25166115     25166115_0  2025-09-04T00:00:00.000
# 197417    25159707     25159707_0  2025-08-26T00:00:00.000
# 197418  C259034450   C259034450_0  2025-08-26T00:00:00.000
#
#                        date_occ time_occ area    area_name rpt_dist_no  \
# 6       2025-09-17T00:00:00.000      530   10  West Valley        1004
# 27      2025-09-09T00:00:00.000        0   20      Olympic        2025
# 57      2025-03-02T00:00:00.000     1530   18    Southeast        1863
# 59      2025-02-21T00:00:00.000      736    3    Southwest         397
# 70      2025-05-24T00:00:00.000     1355    7     Wilshire         765
# ...                         ...      ...  ...          ...         ...
# 197393  2025-09-04T00:00:00.000     2315    6    Hollywood         646
# 197405  2025-05-16T00:00:00.000      930   14      Pacific        1415
# 197410  2025-09-04T00:00:00.000     1630   19      Mission        1964
# 197417  2025-08-26T00:00:00.000     2056   15  N Hollywood        1548
# 197418  2025-08-26T00:00:00.000     1400   20      Olympic        2023
#
#        totalvictimcount victim_type victim_shot status  \
# 6                     2      Person          No     10
# 27                    2      Person          No     40
# 57                    2      Person          No     40
# 59                    2      Person          No     40
# 70                    2      Person          No     40
# ...                 ...         ...         ...    ...
# 197393                3      Person          No     40
# 197405                2      Person          No     40
# 197410                2    Business          No     40
# 197417                4      Person          No     10
# 197418                2      Person          No     40
#
#                     status_desc vict_age vict_sex            vict_descent
# 6             Cleared by Arrest       42        M                Hispanic
# 27      Investigation Continued       32        M                Hispanic
# 57      Investigation Continued       47        F                Hispanic
# 59      Investigation Continued       43        F  Black/African American
# 70      Investigation Continued       22        F                Hispanic
# ...                         ...      ...      ...                     ...
# 197393  Investigation Continued       20        F         White/Caucasian
# 197405  Investigation Continued       56        F                Hispanic
# 197410  Investigation Continued      NaN      NaN                     NaN
# 197417        Cleared by Arrest       35        F                   Other
# 197418  Investigation Continued      NaN        M                   Other
#
# [36595 rows x 16 columns]

# %%
df_off[df_off["caseno"]=="25174642"]
# Out:
#           caseno    uniquenibrno                date_rptd  \
# 197892  25174642  25174642_13A_1  2025-09-17T00:00:00.000
# 200841  25174642  25174642_13C_0  2025-09-17T00:00:00.000
#
#                        date_occ time_occ area    area_name rpt_dist_no  \
# 197892  2025-09-17T00:00:00.000      530   10  West Valley        1004
# 200841  2025-09-17T00:00:00.000      530   10  West Valley        1004
#
#        totaloffensecount group  ...        status_desc totalvictimcount  \
# 197892                 2     A  ...  Cleared by Arrest                2
# 200841                 2     A  ...  Cleared by Arrest                2
#
#        victim_shot domestic_violence_crime hate_crime gang_related_crime  \
# 197892          No                      No         No                 No
# 200841          No                      No         No                 No
#
#        transit_related_crime homeless_victim_crime homeless_suspect_crime  \
# 197892                    No                    No                     No
# 200841                    No                    No                     No
#
#        homeless_arrestee_crime
# 197892                      No
# 200841                      No
#
# [2 rows x 28 columns]

# %%
df_vic[df_vic["caseno"]=="25174642"]
# Out:
#         caseno uniquevictimno                date_rptd  \
# 6     25174642     25174642_1  2025-09-17T00:00:00.000
# 1619  25174642     25174642_0  2025-09-17T00:00:00.000
#
#                      date_occ time_occ area    area_name rpt_dist_no  \
# 6     2025-09-17T00:00:00.000      530   10  West Valley        1004
# 1619  2025-09-17T00:00:00.000      530   10  West Valley        1004
#
#      totalvictimcount victim_type victim_shot status        status_desc  \
# 6                   2      Person          No     10  Cleared by Arrest
# 1619                2      Person          No     10  Cleared by Arrest
#
#      vict_age vict_sex vict_descent
# 6          42        M     Hispanic
# 1619       37        F     Hispanic

# %%
df[df["caseno"]=="25174642"]
# Out:
#           caseno    uniquenibrno              date_rptd_x  \
# 226745  25174642  25174642_13A_1  2025-09-17T00:00:00.000
# 226746  25174642  25174642_13A_1  2025-09-17T00:00:00.000
# 230063  25174642  25174642_13C_0  2025-09-17T00:00:00.000
# 230064  25174642  25174642_13C_0  2025-09-17T00:00:00.000
#
#                      date_occ_x time_occ_x area_x  area_name_x rpt_dist_no_x  \
# 226745  2025-09-17T00:00:00.000        530     10  West Valley          1004
# 226746  2025-09-17T00:00:00.000        530     10  West Valley          1004
# 230063  2025-09-17T00:00:00.000        530     10  West Valley          1004
# 230064  2025-09-17T00:00:00.000        530     10  West Valley          1004
#
#        totaloffensecount group  ...  area_name_y rpt_dist_no_y  \
# 226745                 2     A  ...  West Valley          1004
# 226746                 2     A  ...  West Valley          1004
# 230063                 2     A  ...  West Valley          1004
# 230064                 2     A  ...  West Valley          1004
#
#        totalvictimcount_y victim_type victim_shot_y status_y  \
# 226745                  2      Person            No       10
# 226746                  2      Person            No       10
# 230063                  2      Person            No       10
# 230064                  2      Person            No       10
#
#             status_desc_y vict_age vict_sex vict_descent
# 226745  Cleared by Arrest       42        M     Hispanic
# 226746  Cleared by Arrest       37        F     Hispanic
# 230063  Cleared by Arrest       42        M     Hispanic
# 230064  Cleared by Arrest       37        F     Hispanic
#
# [4 rows x 43 columns]
